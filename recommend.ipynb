# %% [markdown]
# # FoodExplorer: Your Personal Restaurant Recommendation App for Philadelphia
#
# Discover the flavors of Philadelphia with FoodExplorer, the ultimate restaurant recommendation app. Input your location, choose your favorite cuisine category, and set your preferred distance. FoodExplorer will provide you with personalized restaurant suggestions on an interactive map, making it easy to find the perfect dining spot. Whether you're a local or a visitor, FoodExplorer ensures you'll experience the best culinary delights Philadelphia has to offer. Download now and embark on a delicious journey through the City of Brotherly Love.

# %%
import ui
ui.show_ui()
# Out:
# Text(value='1400 John F Kennedy Blvd, Philadelphia, PA 19107', description='Your location:', layout=Layout(wid…
# Text(value='1', description='User ID:', layout=Layout(width='400px'), placeholder='Enter here')
# Dropdown(description='Categoty:', index=19, layout=Layout(width='400px'), options=('American (New)', 'American…
# FloatSlider(value=7.0, description='Distance:', layout=Layout(width='400px'), max=10.0, step=0.5)
# IntSlider(value=11, description='# of recommendations:', layout=Layout(width='400px'), max=20, min=1)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
# ...
